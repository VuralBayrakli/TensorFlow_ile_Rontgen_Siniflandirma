# %%
import tensorflow as tf
import cv2
import imghdr
import numpy as np
import matplotlib.pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory("data")
data = data.map(lambda x, y: (x / 255, y))
train_size = int(len(data) * 0.70)
val_size = int(len(data) * 0.20)
test_size = int(len(data) * 0.10)
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size + val_size).take(test_size)
# Out:
# Found 3292 files belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from keras.layers import LeakyReLU


model = Sequential()


model.add(Dense(16, activation='relu', input_shape=(256,256,3)))
model.add(Flatten())

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 256, 256, 16)      64
#
#  flatten_1 (Flatten)         (None, 1048576)           0
#
#  dense_3 (Dense)             (None, 1)                 1048577
#
# =================================================================
# Total params: 1,048,641
# Trainable params: 1,048,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train, epochs=30, validation_data=val)
# Out:
# Epoch 1/30
# 72/72 [==============================] - 44s 598ms/step - loss: 5.2282 - accuracy: 0.7704 - val_loss: 0.6704 - val_accuracy: 0.9125
# Epoch 2/30
# 72/72 [==============================] - 49s 663ms/step - loss: 0.8482 - accuracy: 0.8863 - val_loss: 0.4060 - val_accuracy: 0.9328
# Epoch 3/30
# 72/72 [==============================] - 47s 631ms/step - loss: 0.7449 - accuracy: 0.8911 - val_loss: 0.6268 - val_accuracy: 0.9047
# Epoch 4/30
# 72/72 [==============================] - 51s 689ms/step - loss: 0.5660 - accuracy: 0.9084 - val_loss: 0.2444 - val_accuracy: 0.9422
# Epoch 5/30
# 72/72 [==============================] - 49s 661ms/step - loss: 0.3711 - accuracy: 0.9240 - val_loss: 0.2590 - val_accuracy: 0.9453
# Epoch 6/30
# 72/72 [==============================] - 51s 687ms/step - loss: 0.3837 - accuracy: 0.9167 - val_loss: 0.3121 - val_accuracy: 0.9344
# Epoch 7/30
# 72/72 [==============================] - 48s 643ms/step - loss: 0.3399 - accuracy: 0.9253 - val_loss: 0.3578 - val_accuracy: 0.9156
# Epoch 8/30
# 72/72 [==============================] - 48s 654ms/step - loss: 0.2281 - accuracy: 0.9336 - val_loss: 0.1903 - val_accuracy: 0.9344
# Epoch 9/30
# 72/72 [==============================] - 52s 710ms/step - loss: 0.1684 - accuracy: 0.9453 - val_loss: 0.3050 - val_accuracy: 0.9109
# Epoch 10/30
# 72/72 [==============================] - 51s 691ms/step - loss: 0.2386 - accuracy: 0.9293 - val_loss: 0.1864 - val_accuracy: 0.9406
# Epoch 11/30
# 72/72 [==============================] - 47s 637ms/step - loss: 0.1357 - accuracy: 0.9531 - val_loss: 0.2220 - val_accuracy: 0.9156
# Epoch 12/30
# 72/72 [==============================] - 48s 646ms/step - loss: 0.1251 - accuracy: 0.9497 - val_loss: 0.1739 - val_accuracy: 0.9438
# Epoch 13/30
# 72/72 [==============================] - 47s 636ms/step - loss: 0.1207 - accuracy: 0.9575 - val_loss: 0.1507 - val_accuracy: 0.9422
# Epoch 14/30
# 72/72 [==============================] - 47s 636ms/step - loss: 0.1064 - accuracy: 0.9601 - val_loss: 0.1248 - val_accuracy: 0.9578
# Epoch 15/30
# 72/72 [==============================] - 51s 686ms/step - loss: 0.0973 - accuracy: 0.9679 - val_loss: 0.1770 - val_accuracy: 0.9312
# Epoch 16/30
# 72/72 [==============================] - 52s 703ms/step - loss: 0.0989 - accuracy: 0.9614 - val_loss: 0.1895 - val_accuracy: 0.9391
# Epoch 17/30
# 72/72 [==============================] - 49s 663ms/step - loss: 0.0816 - accuracy: 0.9666 - val_loss: 0.1299 - val_accuracy: 0.9500
# Epoch 18/30
# 72/72 [==============================] - 48s 653ms/step - loss: 0.0623 - accuracy: 0.9796 - val_loss: 0.1621 - val_accuracy: 0.9391
# Epoch 19/30
# 72/72 [==============================] - 60s 812ms/step - loss: 0.0644 - accuracy: 0.9748 - val_loss: 0.1332 - val_accuracy: 0.9547
# Epoch 20/30
# 72/72 [==============================] - 67s 910ms/step - loss: 0.0677 - accuracy: 0.9792 - val_loss: 0.1835 - val_accuracy: 0.9359
# Epoch 21/30
# 72/72 [==============================] - 78s 1s/step - loss: 0.0978 - accuracy: 0.9562 - val_loss: 0.1629 - val_accuracy: 0.9453
# Epoch 22/30
# 72/72 [==============================] - 68s 926ms/step - loss: 0.0923 - accuracy: 0.9653 - val_loss: 0.2596 - val_accuracy: 0.9078
# Epoch 23/30
# 72/72 [==============================] - 61s 826ms/step - loss: 0.0807 - accuracy: 0.9701 - val_loss: 0.1592 - val_accuracy: 0.9453
# Epoch 24/30
# 72/72 [==============================] - 69s 933ms/step - loss: 0.0989 - accuracy: 0.9631 - val_loss: 0.1594 - val_accuracy: 0.9406
# Epoch 25/30
# 72/72 [==============================] - 69s 932ms/step - loss: 0.0436 - accuracy: 0.9878 - val_loss: 0.1295 - val_accuracy: 0.9547
# Epoch 26/30
# 72/72 [==============================] - 70s 937ms/step - loss: 0.0566 - accuracy: 0.9839 - val_loss: 0.2964 - val_accuracy: 0.9031
# Epoch 27/30
# 72/72 [==============================] - 68s 914ms/step - loss: 0.0644 - accuracy: 0.9748 - val_loss: 0.1367 - val_accuracy: 0.9563
# Epoch 28/30
# 72/72 [==============================] - 51s 685ms/step - loss: 0.0368 - accuracy: 0.9891 - val_loss: 0.1322 - val_accuracy: 0.9516
# Epoch 29/30
# 72/72 [==============================] - 52s 701ms/step - loss: 0.1189 - accuracy: 0.9549 - val_loss: 0.1157 - val_accuracy: 0.9563
# Epoch 30/30
# 72/72 [==============================] - 51s 689ms/step - loss: 0.0383 - accuracy: 0.9883 - val_loss: 0.1268 - val_accuracy: 0.9578

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 30), hist.history["loss"], label="train_loss")
plt.plot(np.arange(0, 30), hist.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 30), hist.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 30), hist.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], label='Training Loss', color='blue')
plt.plot(hist.history['val_loss'], label='Validation Loss', color='red')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %%
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall

pre = Precision()
rec = Recall()
acc = BinaryAccuracy()
for batch in test.as_numpy_iterator():
    x, y = batch
    y_pred = model.predict(x)
    pre.update_state(y, y_pred)
    rec.update_state(y, y_pred)
    acc.update_state(y, y_pred)
print("Precision: {:.3f}".format(pre.result().numpy()))
print("Recall: {:.3f}".format(rec.result().numpy()))
print("Accuracy: {:.3f}".format(acc.result().numpy()))
# Out:
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 248ms/step
# Precision: 0.939
# Recall: 0.927
# Accuracy: 0.931

# %%
img = cv2.imread(r"normalexmp4.jpg")
plt.imshow(img)
plt.show()

# %%
resize = cv2.resize(img, (256, 256))
plt.imshow(resize.astype(np.uint8))
plt.show()

# %%
# np.expand_dims(resize, axis=0).shape
y_pred = model.predict(np.expand_dims(resize/255, axis=0))
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
# y_pred > 0.5 # hasta
# y_pred < 0.5 # normal anlamına geliyor
y_pred
# Out:
# array([[2.2093325e-05]], dtype=float32)

# %%
img = cv2.imread(r"hastaexmp4.jpg")
plt.imshow(img)
plt.show()

# %%
resize = cv2.resize(img, (256, 256))
plt.imshow(resize.astype(np.uint8))
plt.show()

# %%
# np.expand_dims(resize, axis=0).shape
y_pred = model.predict(np.expand_dims(resize/255, axis=0))
# Out:
# 1/1 [==============================] - 1s 615ms/step

# %%
# y_pred > 0.5 # hasta
# y_pred < 0.5 # normal
y_pred
# Out:
# array([[0.9999999]], dtype=float32)

# %%
from tensorflow.keras.models import load_model
import os

# %%
model.save(os.path.join("models", "FC(first)model.h5"))
